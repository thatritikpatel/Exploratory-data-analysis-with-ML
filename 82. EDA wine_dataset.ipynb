# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./Wine_Dataset.csv') 
df
# Out:
#      Malic acid  Ashe  Alcalinity of ashe  Magnesium  Total phenols  \
# 0         14.23  1.71                2.43       15.6            127
# 1         13.20  1.78                2.14       11.2            100
# 2         13.16  2.36                2.67       18.6            101
# 3         14.37  1.95                2.50       16.8            113
# 4         13.24  2.59                2.87       21.0            118
# ..          ...   ...                 ...        ...            ...
# 173       13.71  5.65                2.45       20.5             95
# 174       13.40  3.91                2.48       23.0            102
# 175       13.27  4.28                2.26       20.0            120
# 176       13.17  2.59                2.37       20.0            120
# 177       14.13  4.10                2.74       24.5             96
#
#      Flavanoidse  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# 0           2.80                  3.06             0.28             2.29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Malic acid            178 non-null    float64
#  1   Ashe                  178 non-null    float64
#  2   Alcalinity of ashe    178 non-null    float64
#  3   Magnesium             178 non-null    float64
#  4   Total phenols         178 non-null    int64
#  5   Flavanoidse           178 non-null    float64
#  6   Nonflavanoid phenols  178 non-null    float64
#  7   Proanthocyanins       178 non-null    float64
#  8   Color intensity       178 non-null    float64
#  9   OD280                 178 non-null    float64
#  10  OD31                  178 non-null    float64
#  11  Proline               178 non-null    float64
#  12  Alcohol               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
sns.boxplot(x = df['Malic acid'],data=df)
# Out:
# <Axes: xlabel='Malic acid'>

# %%
col= df.drop('Alcohol',axis=1)

# %%
col
# Out:
#      Malic acid  Ashe  Alcalinity of ashe  Magnesium  Total phenols  \
# 0         14.23  1.71                2.43       15.6            127
# 1         13.20  1.78                2.14       11.2            100
# 2         13.16  2.36                2.67       18.6            101
# 3         14.37  1.95                2.50       16.8            113
# 4         13.24  2.59                2.87       21.0            118
# ..          ...   ...                 ...        ...            ...
# 173       13.71  5.65                2.45       20.5             95
# 174       13.40  3.91                2.48       23.0            102
# 175       13.27  4.28                2.26       20.0            120
# 176       13.17  2.59                2.37       20.0            120
# 177       14.13  4.10                2.74       24.5             96
#
#      Flavanoidse  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# 0           2.80                  3.06             0.28             2.29
# ...

# %%
for cols in col :
    plt.title(f"The Boxplot of {cols}")
    sns.boxplot(x = df[cols],data= df)
    plt.show()

# %%
Q1,Q3 = np.percentile(df['Ashe'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['Ashe']>LF) & (df['Ashe'] <UF)]

# %%
df
# Out:
#      Malic acid  Ashe  Alcalinity of ashe  Magnesium  Total phenols  \
# 0         14.23  1.71                2.43       15.6            127
# 1         13.20  1.78                2.14       11.2            100
# 2         13.16  2.36                2.67       18.6            101
# 3         14.37  1.95                2.50       16.8            113
# 4         13.24  2.59                2.87       21.0            118
# ..          ...   ...                 ...        ...            ...
# 172       14.16  2.51                2.48       20.0             91
# 174       13.40  3.91                2.48       23.0            102
# 175       13.27  4.28                2.26       20.0            120
# 176       13.17  2.59                2.37       20.0            120
# 177       14.13  4.10                2.74       24.5             96
#
#      Flavanoidse  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# 0           2.80                  3.06             0.28             2.29
# ...

# %%
Q1,Q3 = np.percentile(df['Alcalinity of ashe'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['Alcalinity of ashe']>LF) & (df['Alcalinity of ashe'] <UF)]

# %%
df
# Out:
#      Malic acid  Ashe  Alcalinity of ashe  Magnesium  Total phenols  \
# 0         14.23  1.71                2.43       15.6            127
# 1         13.20  1.78                2.14       11.2            100
# 2         13.16  2.36                2.67       18.6            101
# 3         14.37  1.95                2.50       16.8            113
# 4         13.24  2.59                2.87       21.0            118
# ..          ...   ...                 ...        ...            ...
# 172       14.16  2.51                2.48       20.0             91
# 174       13.40  3.91                2.48       23.0            102
# 175       13.27  4.28                2.26       20.0            120
# 176       13.17  2.59                2.37       20.0            120
# 177       14.13  4.10                2.74       24.5             96
#
#      Flavanoidse  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# 0           2.80                  3.06             0.28             2.29
# ...

# %%
Q1,Q3 = np.percentile(df['Magnesium'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['Magnesium']>LF) & (df['Magnesium'] <UF)]

# %%
Q1,Q3 = np.percentile(df['Total phenols'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['Total phenols']>LF) & (df['Total phenols'] <UF)]

# %%
Q1,Q3 = np.percentile(df['Color intensity'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['Color intensity']>LF) & (df['Color intensity'] <UF)]

# %%
Q1,Q3 = np.percentile(df['OD280'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['OD280']>LF) & (df['OD280'] <UF)]

# %%
Q1,Q3 = np.percentile(df['OD31'],[25,75])
IQR = Q3-Q1
LF = Q1-1.5 * IQR
UF =Q3 + 1.5* IQR
df= df[(df['OD31']>LF) & (df['OD31'] <UF)]

# %%
df
# Out:
#      Malic acid  Ashe  Alcalinity of ashe  Magnesium  Total phenols  \
# 0         14.23  1.71                2.43       15.6            127
# 1         13.20  1.78                2.14       11.2            100
# 2         13.16  2.36                2.67       18.6            101
# 3         14.37  1.95                2.50       16.8            113
# 4         13.24  2.59                2.87       21.0            118
# ..          ...   ...                 ...        ...            ...
# 172       14.16  2.51                2.48       20.0             91
# 174       13.40  3.91                2.48       23.0            102
# 175       13.27  4.28                2.26       20.0            120
# 176       13.17  2.59                2.37       20.0            120
# 177       14.13  4.10                2.74       24.5             96
#
#      Flavanoidse  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# 0           2.80                  3.06             0.28             2.29
# ...

# %%
for cols in col:
    plt.title(f"The scatterplot of {cols} and Alcohol")
    sns.scatterplot(x=cols, y='Alcohol',hue='Alcohol',palette =  ['red','blue','green'], data=df)
    plt.show()

# %%
sns.scatterplot(x= df['Malic acid'],y = df['Magnesium'],hue = 'Alcohol',palette = ['red','blue','green'],data=df)
# Out:
# <Axes: xlabel='Malic acid', ylabel='Magnesium'>

# %%
sns.scatterplot(x= df['Ashe'],y = df['Alcalinity of ashe'],hue = 'Alcohol',palette= 'coolwarm',data=df)
# Out:
# <Axes: xlabel='Ashe', ylabel='Alcalinity of ashe'>

# %%
sns.scatterplot(x= df['Flavanoidse'],y = df['Nonflavanoid phenols'],hue = 'Alcohol',palette= 'viridis',data=df)
# Out:
# <Axes: xlabel='Flavanoidse', ylabel='Nonflavanoid phenols'>

# %%
sns.scatterplot(x= df['Proanthocyanins'],y = df['Color intensity'],hue = 'Alcohol',palette=['red','blue','green'] ,data=df)
# Out:
# <Axes: xlabel='Proanthocyanins', ylabel='Color intensity'>

# %%
sns.scatterplot(x= df['OD280'],y = df['OD31'],hue = 'Alcohol',palette= 'viridis',data=df)
# Out:
# <Axes: xlabel='OD280', ylabel='OD31'>

# %%
sns.scatterplot(x= df['Total phenols'],y = df['Proline'],hue = 'Alcohol',palette= 'coolwarm',data=df)
# Out:
# <Axes: xlabel='Total phenols', ylabel='Proline'>

# %%
X = df.drop('Alcohol',axis=1)
Y = df['Alcohol']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y ,test_size = 0.2,random_state = 1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print("The accuracy of this model is :",accuracy_score(y_pred,Y_test))
print("\n")
print("The confusion matrix of this model is :",confusion_matrix(y_pred,Y_test))
# Out:
# The accuracy of this model is : 0.9090909090909091
#
#
# The confusion matrix of this model is : [[12  0  0]
#  [ 2 12  0]
#  [ 0  1  6]]

# %%
df['Alcohol'].value_counts()
# Out:
# 2    61
# 1    57
# 3    43
# Name: Alcohol, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
param = {'penalty': ('l1', 'l2', 'elasticnet'), 'C': [1, 5, 9, 12], 'l1_ratio': [0.1, 0.5, 0.7]}
clf = GridSearchCV(model, param_grid=param, cv=5)
clf.fit(X_train, Y_train)
best_score = clf.best_score_

# %%
print("By doing hyperparameter tunning is :",best_score)
# Out:
# By doing hyperparameter tunning is : 0.9378461538461538

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
nb_clf = GaussianNB()
lr_clf = LogisticRegression()
dt_clf = DecisionTreeClassifier()
svm_clf = SVC(kernel = 'linear',probability = True)

# %%
from sklearn.ensemble import VotingClassifier
estimator = [('decision_tree',dt_clf),('naive_bayes',nb_clf),('log_reg',lr_clf),('svm',svm_clf)]
ensemble_clf = VotingClassifier(estimators=estimator,voting='soft')
ensemble_clf.fit(X_train,Y_train)
y_ensemble_pred = ensemble_clf.predict(X_test)

# %%
print("By Bagging the accuracy of this model is :",accuracy_score(y_ensemble_pred,Y_test))
# Out:
# By Bagging the accuracy of this model is : 0.9696969696969697

# %%
# By using Boosting method :->
from sklearn.ensemble import AdaBoostClassifier
classifier = AdaBoostClassifier()
classifier.fit(X_train,Y_train)
y_boosting_pred= classifier.predict(X_test)
print("The Accuracy score is by using Adaboostingmethod: ",accuracy_score(y_boosting_pred,Y_test))
# Out:
# The Accuracy score is by using Adaboostingmethod: 0.5757575757575758

# %%
from sklearn.ensemble import GradientBoostingClassifier
classifier = GradientBoostingClassifier()
classifier.fit(X_train,Y_train)
y_boosting_pred= classifier.predict(X_test)
print("The Accuracy score is by using Gradiet Boosting method:",accuracy_score(y_boosting_pred,Y_test))
print("The confusion matrix is :\n",confusion_matrix(y_boosting_pred,Y_test))
# Out:
# The Accuracy score is by using Gradiet Boosting method: 1.0
# The confusion matrix is :
#  [[14  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
