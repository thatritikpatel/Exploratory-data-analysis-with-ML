# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("mumbai_flats_price.csv")

# %%
df.shape
# Out:
# (7483, 10)

# %%
df.head()
# Out:
#     flat_type  flat_price       location1  buildupArea_sqft  \
# 0  2 BHK Flat        0.95  Mira Road East              1060
# 1  1 BHK Flat        0.93   Borivali East               525
# 2  2 BHK Flat        1.48    Bhandup West              1065
# 3  3 BHK Flat        2.50    Bhandup West              1150
# 4  1 BHK Flat        1.10     Wadala East               480
#
#        age_of_property      furnishing  bedrooms  bathrooms  balcony parking
# 0  recent construction  Semi Furnished         2          2        0     yes
# 1     mid age property  Semi Furnished         1          2        0      no
# 2     new construction  Semi Furnished         2          2        1     yes
# 3  recent construction  Semi Furnished         3          2        0     yes
# 4     new construction     Unfurnished         1          2        0     yes

# %%
df.isnull().sum()
# Out:
# flat_type           0
# flat_price          0
# location1           0
# buildupArea_sqft    0
# age_of_property     0
# furnishing          0
# bedrooms            0
# bathrooms           0
# balcony             0
# parking             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 110

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7373 entries, 0 to 7482
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   flat_type         7373 non-null   object
#  1   flat_price        7373 non-null   float64
#  2   location1         7373 non-null   object
#  3   buildupArea_sqft  7373 non-null   int64
#  4   age_of_property   7373 non-null   object
#  5   furnishing        7373 non-null   object
#  6   bedrooms          7373 non-null   int64
#  7   bathrooms         7373 non-null   int64
#  8   balcony           7373 non-null   int64
#  9   parking           7373 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 633.6+ KB

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'object']

# %%
for col in cat_col:
    print(col, df[col].unique())
# Out:
# flat_type ['2 BHK Flat' '1 BHK Flat' '3 BHK Flat' '4 BHK Flat' '6 BHK Flat'
#  '5 BHK Flat']
# location1 ['Mira Road East' 'Borivali East' 'Bhandup West' 'Wadala East'
#  'Thane West' 'Goregaon East' 'Powai' 'Goregaon West' 'Kandivali West'
#  'Kurla East' 'Lower Parel' 'Vikhroli East' 'Kurla West' 'Chembur'
#  'Kandivali East' 'Nalasopara East' 'Parel' 'Virar West' 'Sion'
#  'Malad West' 'Mulund West' 'Andheri East' 'Khar West' 'Naigaon East'
#  'Santacruz East' 'Jogeshwari West' 'Vile Parle East' 'Andheri West'
#  'Borivali West' 'Santacruz West' 'Mulund East' 'Kanjurmarg East'
#  'Govandi' 'Jogeshwari East' 'Mahim' 'Vasai East' 'Dadar East'
#  'Vile Parle West' 'Nalasopara West' 'Bhayandar West' 'Mumbai Central'
#  'Worli' 'Matunga East' 'Bandra West' 'Churchgate' 'Vasai West' 'Agripada'
#  'Dahisar East' 'Kanjurmarg West' 'Bandra East' 'Dahisar West'
#  'Mahalakshmi' 'Dadar West' 'Cuffe Parade' 'Byculla' 'Bhayandar East'
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in cat_col:
    df[col] = le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7373 entries, 0 to 7482
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   flat_type         7373 non-null   int64
#  1   flat_price        7373 non-null   float64
#  2   location1         7373 non-null   int64
#  3   buildupArea_sqft  7373 non-null   int64
#  4   age_of_property   7373 non-null   int64
#  5   furnishing        7373 non-null   int64
#  6   bedrooms          7373 non-null   int64
#  7   bathrooms         7373 non-null   int64
#  8   balcony           7373 non-null   int64
#  9   parking           7373 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 633.6 KB

# %%
df = df.rename(columns={'flat_price': 'flat_price(in cr)'})

# %%
df.head()
# Out:
#    flat_type  flat_price(in cr)  location1  buildupArea_sqft  age_of_property  \
# 0          1               0.95         50              1060                4
# 1          0               0.93         10               525                0
# 2          1               1.48          6              1065                2
# 3          2               2.50          6              1150                4
# 4          0               1.10         77               480                2
#
#    furnishing  bedrooms  bathrooms  balcony  parking
# 0           1         2          2        0        1
# 1           1         1          2        0        0
# 2           1         2          2        1        1
# 3           1         3          2        0        1
# 4           2         1          2        0        1

# %%
X = df.drop('flat_price(in cr)', axis=1)
y = df['flat_price(in cr)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
from xgboost import XGBRegressor
model = XGBRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8599391263419331

# %%
param_grid = {
    'n_estimators': [100, 200, 250, 300, 500],
    'learning_rate': [0.01, 0.05, 0.1, 0.2]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 300}

# %%
grid.best_score_
# Out:
# 0.8689276696448971

# %%
y_pred_grid = grid.predict(X_test)

# %%
print(r2_score(y_test, y_pred_grid))
# Out:
# 0.8591909777213342
