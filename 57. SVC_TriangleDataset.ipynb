# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('triangle_dataset.csv')

# %%
df.shape
# Out:
# (30000, 4)

# %%
df.head()
# Out:
#    Side_A  Side_B  Side_C Triangle_Type
# 0    98.0    98.0    98.0   Equilateral
# 1    41.0    41.0    41.0   Equilateral
# 2    76.0    76.0    76.0   Equilateral
# 3     2.0     2.0     2.0   Equilateral
# 4    35.0    35.0    35.0   Equilateral

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Side_A         30000 non-null  float64
#  1   Side_B         30000 non-null  float64
#  2   Side_C         30000 non-null  float64
#  3   Triangle_Type  30000 non-null  object
# dtypes: float64(3), object(1)
# memory usage: 937.6+ KB

# %%
df['Triangle_Type'].value_counts()
# Out:
# Triangle_Type
# Equilateral    10000
# Isosceles      10000
# Scalene        10000
# Name: count, dtype: int64

# %%
df['Triangle_Type'] = df['Triangle_Type'].map({'Equilateral':0,'Isosceles':1,'Scalene':2})

# %%
df.isnull().sum()
# Out:
# Side_A           0
# Side_B           0
# Side_C           0
# Triangle_Type    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8411

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21589 entries, 0 to 29999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Side_A         21589 non-null  float64
#  1   Side_B         21589 non-null  float64
#  2   Side_C         21589 non-null  float64
#  3   Triangle_Type  21589 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 843.3 KB

# %%
X = df.drop('Triangle_Type',axis=1)
y = df['Triangle_Type']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=12)

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model
# Out:
# SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6586382584529875
