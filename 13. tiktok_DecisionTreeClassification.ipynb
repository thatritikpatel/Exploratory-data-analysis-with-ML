# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd. read_csv("datasets/tiktok_dataset.csv" )

# %%
df.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
df.shape
# Out:
# (19382, 12)

# %%
df.describe().T
# Out:
#                         count          mean           std           min  \
# #                     19382.0  9.691500e+03  5.595246e+03  1.000000e+00
# video_id              19382.0  5.627454e+09  2.536440e+09  1.234959e+09
# video_duration_sec    19382.0  3.242173e+01  1.622997e+01  5.000000e+00
# video_view_count      19084.0  2.547086e+05  3.228933e+05  2.000000e+01
# video_like_count      19084.0  8.430464e+04  1.334205e+05  0.000000e+00
# video_share_count     19084.0  1.673525e+04  3.203617e+04  0.000000e+00
# video_download_count  19084.0  1.049430e+03  2.004300e+03  0.000000e+00
# video_comment_count   19084.0  3.493121e+02  7.996389e+02  0.000000e+00
#
#                                25%           50%           75%           max
# #                     4.846250e+03  9.691500e+03  1.453675e+04  1.938200e+04
# video_id              3.430417e+09  5.618664e+09  7.843960e+09  9.999873e+09
# video_duration_sec    1.800000e+01  3.200000e+01  4.700000e+01  6.000000e+01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
df.claim_status.unique()
# Out:
# array(['claim', 'opinion', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# #                             0
# claim_status                298
# video_id                      0
# video_duration_sec            0
# video_transcription_text    298
# verified_status               0
# author_ban_status             0
# video_view_count            298
# video_like_count            298
# video_share_count           298
# video_download_count        298
# video_comment_count         298
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# #                           0
# claim_status                0
# video_id                    0
# video_duration_sec          0
# video_transcription_text    0
# verified_status             0
# author_ban_status           0
# video_view_count            0
# video_like_count            0
# video_share_count           0
# video_download_count        0
# video_comment_count         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19084 entries, 0 to 19083
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19084 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19084 non-null  int64
#  3   video_duration_sec        19084 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19084 non-null  object
#  6   author_ban_status         19084 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.9+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.claim_status.value_counts()
# Out:
# claim_status
# claim      9608
# opinion    9476
# Name: count, dtype: int64

# %%
df=df.drop('#', axis =1)

# %%
df.head(4)
# Out:
#   claim_status    video_id  video_duration_sec  \
# 0        claim  7017666017                  59
# 1        claim  4014381136                  32
# 2        claim  9859838091                  31
# 3        claim  1866847991                  25
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# 2            active          902185.0           97690.0             2858.0
# 3            active          437506.0          239954.0            34812.0
#
# ...

# %%
df.drop('video_duration_sec', axis =1,inplace =True)

# %%
df.drop('video_transcription_text', axis =1,inplace =True)

# %%
df.head(2)
# Out:
#   claim_status    video_id verified_status author_ban_status  \
# 0        claim  7017666017    not verified      under review
# 1        claim  4014381136    not verified            active
#
#    video_view_count  video_like_count  video_share_count  \
# 0          343296.0           19425.0              241.0
# 1          140877.0           77355.0            19034.0
#
#    video_download_count  video_comment_count
# 0                   1.0                  0.0
# 1                1161.0                684.0

# %%
df.verified_status.unique()
# Out:
# array(['not verified', 'verified'], dtype=object)

# %%
df.verified_status = df.verified_status.map({"not verified" :0, "verified" :1})

# %%
df.head(2)
# Out:
#   claim_status    video_id  verified_status author_ban_status  \
# 0        claim  7017666017                0      under review
# 1        claim  4014381136                0            active
#
#    video_view_count  video_like_count  video_share_count  \
# 0          343296.0           19425.0              241.0
# 1          140877.0           77355.0            19034.0
#
#    video_download_count  video_comment_count
# 0                   1.0                  0.0
# 1                1161.0                684.0

# %%
df.author_ban_status.unique()
# Out:
# array(['under review', 'active', 'banned'], dtype=object)

# %%
df.author_ban_status.value_counts()
# Out:
# author_ban_status
# active          15383
# under review     2066
# banned           1635
# Name: count, dtype: int64

# %%
df.author_ban_status = df.author_ban_status.map({"under review" :1,"active":2,"banned" :0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19084 entries, 0 to 19083
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   claim_status          19084 non-null  object
#  1   video_id              19084 non-null  int64
#  2   verified_status       19084 non-null  int64
#  3   author_ban_status     19084 non-null  int64
#  4   video_view_count      19084 non-null  float64
#  5   video_like_count      19084 non-null  float64
#  6   video_share_count     19084 non-null  float64
#  7   video_download_count  19084 non-null  float64
#  8   video_comment_count   19084 non-null  float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 1.5+ MB

# %%
df.claim_status.unique()
# Out:
# array(['claim', 'opinion'], dtype=object)

# %%
df.claim_status  = df.claim_status.map({"claim":1,"opinion":0} )

# %%
df.claim_status.unique()
# Out:
# array([1, 0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19084 entries, 0 to 19083
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   claim_status          19084 non-null  int64
#  1   video_id              19084 non-null  int64
#  2   verified_status       19084 non-null  int64
#  3   author_ban_status     19084 non-null  int64
#  4   video_view_count      19084 non-null  float64
#  5   video_like_count      19084 non-null  float64
#  6   video_share_count     19084 non-null  float64
#  7   video_download_count  19084 non-null  float64
#  8   video_comment_count   19084 non-null  float64
# dtypes: float64(5), int64(4)
# memory usage: 1.5 MB

# %%
df.isna().sum()
# Out:
# claim_status            0
# video_id                0
# verified_status         0
# author_ban_status       0
# video_view_count        0
# video_like_count        0
# video_share_count       0
# video_download_count    0
# video_comment_count     0
# dtype: int64

# %% [markdown]
# Dependent and independent variable split

# %%
df
# Out:
#        claim_status    video_id  verified_status  author_ban_status  \
# 0                 1  7017666017                0                  1
# 1                 1  4014381136                0                  2
# 2                 1  9859838091                0                  2
# 3                 1  1866847991                0                  2
# 4                 1  7105231098                0                  2
# ...             ...         ...              ...                ...
# 19079             0  1492320297                0                  2
# 19080             0  9841347807                0                  2
# 19081             0  8024379946                0                  2
# 19082             0  7425795014                0                  2
# 19083             0  4094655375                0                  2
#
#        video_view_count  video_like_count  video_share_count  \
# 0              343296.0           19425.0              241.0
# ...

# %%
X = df.drop("claim_status", axis =1)
y = df.claim_status

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
y_test
# Out:
# 706      1
# 12638    0
# 15719    0
# 14749    0
# 11223    0
#         ..
# 536      1
# 6000     1
# 6458     1
# 0        1
# 5116     1
# Name: claim_status, Length: 4771, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaling = StandardScaler ()

# %%
X_train=Scaling. fit_transform(X_train)

# %%
X_test = Scaling.transform(X_test)

# %% [markdown]
# Building model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Model = DecisionTreeClassifier()

# %%
Model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = Model.predict(X_test)

# %%
Model.score(X_test,y_test)
# Out:
# 0.991406413749738

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    "criterion":['gini', 'entropy'],
    "max_depth":[3,4,5,6],
    "splitter":["best","random"]
}

model = GridSearchCV(estimator=DecisionTreeClassifier(random_state=1),param_grid=param_grid,cv=5,verbose=3,n_jobs=-1)
model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
model.best_score_
# Out:
# np.float64(0.9954586737997728)

# %%
model.score(X_test,y_test)
# Out:
# 0.9958080067071893

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_matrix(y_test,y_pred)
# Out:
# array([[2317,   21],
#        [  20, 2413]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2338
#            1       0.99      0.99      0.99      2433
#
#     accuracy                           0.99      4771
#    macro avg       0.99      0.99      0.99      4771
# weighted avg       0.99      0.99      0.99      4771
