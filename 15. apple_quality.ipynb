# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('datasets/apple_quality.csv')

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.isna().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
df.Acidity.unique()
# Out:
# array(['-0.491590483', '-0.722809367', '2.621636473', ..., '-1.334611391',
#        '-2.229719806', '1.599796456'], dtype=object)

# %%
df['Acidity'] = df.Acidity.astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   float64
#  8   Quality      4000 non-null   object
# dtypes: float64(8), object(1)
# memory usage: 312.5+ KB

# %%
df.Quality.unique()
# Out:
# array(['good', 'bad'], dtype=object)

# %%
df['Quality'] = df.Quality.map({'good':1, 'bad':0})

# %%
df['Quality'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.Quality.value_counts()
# Out:
# Quality
# 1    2004
# 0    1996
# Name: count, dtype: int64

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# ...

# %%
df.drop('A_id', axis=1, inplace=True)

# %%
sns.boxplot(df[df.columns])
plt.xticks(rotation=-40)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Size'),
#   Text(1, 0, 'Weight'),
#   Text(2, 0, 'Sweetness'),
#   Text(3, 0, 'Crunchiness'),
#   Text(4, 0, 'Juiciness'),
#   Text(5, 0, 'Ripeness'),
#   Text(6, 0, 'Acidity'),
#   Text(7, 0, 'Quality')])

# %%
Q1 = df.drop('Quality',axis=1).quantile(0.25)
Q3 = df.drop('Quality',axis=1).quantile(0.75)

IQR = Q3 - Q1

lower_fence = Q1 -1.5 *IQR
upper_fence = Q3 + 1.5 *IQR

# %%
lower_fence
# Out:
# Size          -5.750201
# Weight        -5.075890
# Sweetness     -5.548946
# Crunchiness   -2.684440
# Juiciness     -4.757179
# Ripeness      -4.578510
# Acidity       -5.709299
# dtype: float64

# %%
upper_fence
# Out:
# Size           4.738963
# Weight         3.095097
# Sweetness      4.612442
# Crunchiness    4.641439
# Juiciness      5.791870
# Ripeness       5.573044
# Acidity        5.842368
# dtype: float64

# %%
outlier_treated = {}
for i, col in enumerate(df.columns):
    if df.columns[i] == 'Quality':
        break
    df_outlier = np.where((df[col] >= upper_fence[i]) | (df[col] <= lower_fence[i]), df[col].mean(), df[col])
    outlier_treated[list(df.columns)[i]] = df_outlier
print(outlier_treated)
# Out:
# {'Size': array([-3.97004852, -1.19521719, -0.29202386, ..., -2.6345153 ,
#        -4.00800374,  0.27853965]), 'Weight': array([-2.51233638, -2.83925653, -1.35128199, ..., -2.13824672,
#        -1.77933711, -1.71550503]), 'Sweetness': array([-0.47047852,  3.66405876, -1.73842916, ..., -2.44046129,
#         2.36639697,  0.12121725]), 'Crunchiness': array([-1.01200871,  1.58823231, -0.34261593, ...,  0.65722289,
#        -0.20032937, -1.15407476]), 'Juiciness': array([1.84490036, 0.8532858 , 2.83863551, ..., 2.19970859, 2.16143512,
#        1.2666774 ]), 'Ripeness': array([ 0.3298398 ,  0.86753008, -0.03803333, ...,  4.76385918,
#         0.21448838, -0.77657147]), 'Acidity': array([-0.49159048, -0.72280937,  2.62163647, ..., -1.33461139,
#        -2.22971981,  1.59979646])}

# %%
outlier_treated.keys()
# Out:
# dict_keys(['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity'])

# %%
df_final = pd.DataFrame(outlier_treated, columns=outlier_treated.keys())

# %%
df_final['Quality'] = df.Quality

# %%
df_final
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336  -0.470479    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.491590        1
# 1    -0.722809        1
# 2     2.621636        0
# 3     0.790723        1
# ...

# %%
sns.boxplot(df_final[df_final.columns])
plt.xticks(rotation=40)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Size'),
#   Text(1, 0, 'Weight'),
#   Text(2, 0, 'Sweetness'),
#   Text(3, 0, 'Crunchiness'),
#   Text(4, 0, 'Juiciness'),
#   Text(5, 0, 'Ripeness'),
#   Text(6, 0, 'Acidity'),
#   Text(7, 0, 'Quality')])

# %%
lower_cap = df_final.drop(['Acidity', 'Quality'], axis=1).quantile(0.05)
upper_cap = df_final.drop(['Acidity', 'Quality'], axis=1).quantile(0.95)

# %%
lower_cap
# Out:
# Size          -3.563803
# Weight        -3.592597
# Sweetness     -3.602018
# Crunchiness   -1.230102
# Juiciness     -2.659703
# Ripeness      -2.549781
# Name: 0.05, dtype: float64

# %%
upper_cap
# Out:
# Size           2.612115
# Weight         1.523348
# Sweetness      2.712652
# Crunchiness    3.133401
# Juiciness      3.563244
# Ripeness       3.520425
# Name: 0.95, dtype: float64

# %%
df_final['Size'] = np.where(df_final['Size'] < lower_cap['Size'], lower_cap['Size'],
        np.where(df_final['Size'] > upper_cap['Size'], upper_cap['Size'],
                df_final['Size']))

# %%
df_final['Weight'] = np.where(df_final['Weight'] < lower_cap['Weight'], lower_cap['Weight'],
        np.where(df_final['Weight'] > upper_cap['Weight'], upper_cap['Weight'],
                df_final['Weight']))
df_final['Sweetness'] = np.where(df_final['Sweetness'] < lower_cap['Sweetness'], lower_cap['Sweetness'],
        np.where(df_final['Sweetness'] > upper_cap['Sweetness'], upper_cap['Sweetness'],
                df_final['Sweetness']))
df_final['Crunchiness'] = np.where(df_final['Crunchiness'] < lower_cap['Crunchiness'], lower_cap['Crunchiness'],
        np.where(df_final['Crunchiness'] > upper_cap['Crunchiness'], upper_cap['Crunchiness'],
                df_final['Crunchiness']))
df_final['Juiciness'] = np.where(df_final['Juiciness'] < lower_cap['Juiciness'], lower_cap['Juiciness'],
                                np.where(df_final['Juiciness'] > upper_cap['Juiciness'], upper_cap['Juiciness'],
                df_final['Juiciness']))
df_final['Ripeness'] = np.where(df_final['Ripeness'] < lower_cap['Ripeness'], lower_cap['Ripeness'],
                               np.where(df_final['Ripeness'] > upper_cap['Ripeness'], upper_cap['Ripeness'],
                df_final['Ripeness']))

# %%
sns.boxplot(df_final[df_final.columns])
plt.xticks(rotation=40)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Size'),
#   Text(1, 0, 'Weight'),
#   Text(2, 0, 'Sweetness'),
#   Text(3, 0, 'Crunchiness'),
#   Text(4, 0, 'Juiciness'),
#   Text(5, 0, 'Ripeness'),
#   Text(6, 0, 'Acidity'),
#   Text(7, 0, 'Quality')])

# %%
# X and y split
x = df_final.drop('Quality', axis= 1)
y = df_final['Quality']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
param = {
    'C':[0.1,0.05,0.3,0.5,1.0],
    'penalty':['l1', 'l2', 'elasticnet'],
    'solver' : ['lbfgs','liblinear']
}

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(LogisticRegression(), param_grid=param, cv=5, verbose=3, scoring='accuracy')

# %%
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.727 total time=   0.0s
# [CV 2/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.714 total time=   0.0s
# [CV 3/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.730 total time=   0.0s
# [CV 4/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.744 total time=   0.0s
# [CV 5/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.711 total time=   0.0s
# [CV 1/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.722 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
cls = LogisticRegression(C=0.1, penalty='l1', solver='liblinear')

# %%
cls.fit(x_train, y_train)
# Out:
# LogisticRegression(C=0.1, penalty='l1', solver='liblinear')

# %%
y_pred = cls.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75       409
#            1       0.73      0.79      0.76       391
#
#     accuracy                           0.75       800
#    macro avg       0.75      0.75      0.75       800
# weighted avg       0.75      0.75      0.75       800
